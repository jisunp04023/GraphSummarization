# %%
import numpy as np
import pandas as pd
import json
import matplotlib.pyplot as plt
import math

"""
Node.csv: 노드 정보
Edge.csv: 엣지 정보

SampledNode.csv: 가중치 계산 시 사용되는 노드 정보
DataAnalysis.xlsx: 노드 세부 정보
"""
# Out:
# '\nNode.csv: 노드 정보\nEdge.csv: 엣지 정보\n\nSampledNode.csv: 가중치 계산 시 사용되는 노드 정보\nDataAnalysis.xlsx: 노드 세부 정보\n'

# %%
data = pd.read_json("./cve_list.txt")
data
# Out:
#                     0                                                  1
# 0    CVE-2017-1000503  {'entities': [['V2_CVSS', 6.8], ['VULNERABILIT...
# 1      CVE-2017-11418  {'entities': [['DRIVER', 'dapur/apps/app_artic...
# 2      CVE-2017-10887  {'entities': [['CWE', 'CWE-426'], ['VULNERABIL...
# 3       CVE-2017-9434  {'entities': [['SOFTWARE', 'cryptopp'], ['SOUR...
# 4      CVE-2017-17575  {'entities': [['SOURCECODE', 'vendor_details.p...
# ..                ...                                                ...
# 448    CVE-2017-16014  {'entities': [['VULNERABILITY', 'dos'], ['V2_C...
# 449    CVE-2017-11439  {'entities': [['VENDER', 'sitecore'], ['CWE', ...
# 450     CVE-2017-2789  {'entities': [['SOFTWARE', 'ichitaro office'],...
# 451     CVE-2017-3156  {'entities': [['VENDER', 'apache'], ['CWE', 'C...
# 452    CVE-2017-17280  {'entities': [['VULNERABILITY', 'info'], ['V2_...
#
# [453 rows x 2 columns]

# %%
node = pd.DataFrame({"Label": data[0]})
node
# Out:
#                 Label
# 0    CVE-2017-1000503
# 1      CVE-2017-11418
# 2      CVE-2017-10887
# 3       CVE-2017-9434
# 4      CVE-2017-17575
# ..                ...
# 448    CVE-2017-16014
# 449    CVE-2017-11439
# 450     CVE-2017-2789
# 451     CVE-2017-3156
# 452    CVE-2017-17280
#
# [453 rows x 1 columns]

# %%
entities = []
for d in data[1]:
    d['entities'] = dict(d['entities'])
    entities.append(d['entities'])
entities = pd.DataFrame(entities)
entities
# Out:
#      V2_CVSS      VULNERABILITY                 STRUCT      CWE  IMPACT  \
# 0        6.8           execcode         race condition  CWE-362     6.4
# 1        7.5                sql                    NaN   CWE-89     6.4
# 2        9.3               priv  untrusted search path  CWE-426    10.0
# 3        5.0            unknown                    NaN  CWE-125     2.9
# 4        7.5                sql                    NaN   CWE-89     6.4
# ..       ...                ...                    ...      ...     ...
# 448      5.0                dos                    NaN  CWE-388     2.9
# 449      3.5                xss                    NaN   CWE-79     2.9
# 450      7.5  execcode overflow                    NaN  CWE-119     6.4
# 451      5.0            unknown                    NaN  CWE-361     2.9
# 452      2.9               info                    NaN  CWE-200     2.9
#
#           VENDER                              DRIVER        SOURCECODE  \
# 0        jenkins                                 NaN               NaN
# 1            NaN  dapur/apps/app_article/controller/  article_list.php
# 2            NaN                                 NaN               NaN
# 3            NaN                                 NaN        zinflate.c
# 4            NaN                                 NaN  item_details.php
# ..           ...                                 ...               ...
# 448          NaN                                 NaN               NaN
# 449     sitecore        shell/applications/tools/run               NaN
# 450  justsystems                                 NaN               NaN
# 451       apache                                 NaN               NaN
# 452       huawei                                 NaN               NaN
#
#              SOFTWARE FUNCTION
# 0                 NaN      NaN
# 1            fiyo cms      NaN
# 2         book walker      NaN
# 3              crypto      NaN
# 4    fs groupon clone      NaN
# ..                ...      ...
# 448        http-proxy      NaN
# 449          sitecore      NaN
# 450   ichitaro office      NaN
# 451               cxf      NaN
# 452      lon-al00bc00      NaN
#
# [453 rows x 10 columns]

# %%
NodeTable = pd.concat([node, entities], axis = 1)
NodeTable.to_csv("Node.csv", index = False)

# %%
# feature들의 NaN 값 frequency
NaN_COUNT = pd.DataFrame({"NaN" : entities.isnull().sum()})

# Label 칼럼 값들의 frequency
CVE_ID = pd.DataFrame(node.value_counts())

# feature들의 label을 index list에 저장
index = entities.keys()

# .xlsx 파일 생성
with pd.ExcelWriter('DataAnalysis.xlsx') as writer:
    NodeTable.to_excel(writer, sheet_name = 'NodeTable')
    NaN_COUNT.to_excel(writer, sheet_name = 'NaN_COUNT')
    CVE_ID.to_excel(writer, sheet_name = 'CVE_ID')
    for i in index:
        pd.DataFrame(entities[i].value_counts()).to_excel(writer, sheet_name = i)

# %%
Sample = NodeTable.loc[:, ['Label', 'V2_CVSS', 'VULNERABILITY', 'STRUCT', 'CWE', 'IMPACT', 'VENDER', 'SOFTWARE']]
Sample
# Out:
#                 Label  V2_CVSS      VULNERABILITY                 STRUCT  \
# 0    CVE-2017-1000503      6.8           execcode         race condition
# 1      CVE-2017-11418      7.5                sql                    NaN
# 2      CVE-2017-10887      9.3               priv  untrusted search path
# 3       CVE-2017-9434      5.0            unknown                    NaN
# 4      CVE-2017-17575      7.5                sql                    NaN
# ..                ...      ...                ...                    ...
# 448    CVE-2017-16014      5.0                dos                    NaN
# 449    CVE-2017-11439      3.5                xss                    NaN
# 450     CVE-2017-2789      7.5  execcode overflow                    NaN
# 451     CVE-2017-3156      5.0            unknown                    NaN
# 452    CVE-2017-17280      2.9               info                    NaN
#
#          CWE  IMPACT       VENDER          SOFTWARE
# 0    CWE-362     6.4      jenkins               NaN
# 1     CWE-89     6.4          NaN          fiyo cms
# 2    CWE-426    10.0          NaN       book walker
# 3    CWE-125     2.9          NaN            crypto
# 4     CWE-89     6.4          NaN  fs groupon clone
# ..       ...     ...          ...               ...
# 448  CWE-388     2.9          NaN        http-proxy
# 449   CWE-79     2.9     sitecore          sitecore
# 450  CWE-119     6.4  justsystems   ichitaro office
# 451  CWE-361     2.9       apache               cxf
# 452  CWE-200     2.9       huawei      lon-al00bc00
#
# [453 rows x 8 columns]

# %%
def ProcessCVSS(x):
    if 0 <= x and x < 2.5:
        return 0
    elif 2.5 <= x and x < 5:
        return 2.5
    elif 5 <= x and x < 7.5:
        return 5
    else:
        return 7.5
    
for i in range(0, len(Sample)):
    Sample.loc[i, 'V2_CVSS'] = ProcessCVSS(Sample.loc[i, 'V2_CVSS'])
    
Sample
Sample.to_csv("SampledNode.csv", index = False)

# %%
software = []
idx = 0

for i in Sample.loc[:, 'SOFTWARE']:
    if type(i) == type('str'):
        l = i.split(" ")
        for j in l:
            software.append([])
            software[idx].append(j)
    else:
        software.append([])
        software[idx].append(math.nan)
    idx += 1

software = software[: idx]
software
# Out:
# [[nan],
#  ['fiyo', 'cms'],
#  ['book', 'walker'],
#  ['crypto'],
#  ['fs', 'groupon', 'clone'],
#  ['relm'],
#  ['android'],
#  ['binutils'],
#  ['zfs', 'storage', 'appliance', 'kit'],
#  ['libav'],
#  ['security', 'access', 'manager', 'appliance'],
#  ['application_helper.rb', ''],
#  ['cubecart'],
#  ['ios'],
#  ['android'],
#  ['backintime'],
#  ['file', 'compact'],
#  ['opentext', 'documentum', 'content', 'server'],
#  ['flatcore'],
#  ['arris', 'nvg599', 'device'],
#  ['synology', 'chat'],
#  ['windows', '8.1'],
#  ['asyncos', 'software'],
#  ['nylas', 'mail', 'lives'],
#  ['timidity'],
#  ['httpd'],
#  ['ios'],
#  ['odl-l2switch-switch'],
#  ['fs', 'lynda', 'clone'],
#  ['elastic', 'services', 'controllers'],
#  ['quantastor', 'v4', 'virtual', 'appliance'],
#  ['sharepoint', 'server'],
#  [nan],
#  ['ar100'],
#  ['swfcombine'],
#  ['yara'],
#  ['prime', 'infrastructure'],
#  ['dotnetnuke'],
#  ['edr-810'],
#  ['afm'],
#  ['uclibc'],
#  ['gnome-session'],
#  ['wireshark'],
#  ['android'],
#  ['securimage'],
#  ['jbig2dec'],
#  ['mlalchemy'],
#  ['windows', '8.1'],
#  ['proxyclient'],
#  ['internet', 'explorer'],
#  ['ts-550', 'evo'],
#  ['linux', 'kernel'],
#  ['integrated', 'lights-out'],
#  ['windows', '8.1'],
#  ['cms', 'made', 'simple'],
#  ['qemu'],
#  ['windows', '8.1'],
#  ['tibco', 'jasperreports', 'server', 'community', 'edition'],
#  ['ios'],
#  ['banco', 'santander', 'mexico', 'sa', 'supermovil'],
#  ['ultra', 'services', 'framework', 'staging', 'server'],
#  ['sd', '650/52'],
#  ['precision', 'optimizer'],
#  ['internet', 'explorer'],
#  ['imc'],
#  ['image', 'viewer'],
#  ['documentum', 'webtop'],
#  ['techno', 'portfolio', 'management', 'panel'],
#  ['gridserver', 'broker'],
#  ['chakracore'],
#  ['security', 'guardium'],
#  ['android'],
#  ['linux', 'kernel'],
#  ['rt-n12vp', 'b1'],
#  ['windows', '10'],
#  ['reader'],
#  ['netbsd'],
#  ['cameras'],
#  [nan],
#  [nan],
#  ['peoplesoft', 'enterprise', 'prtl', 'interaction', 'hub'],
#  ['irfanview'],
#  ['hospitality', 'cruise', 'materials', 'management'],
#  ['goahead', 'webserver'],
#  ['windows', '7'],
#  ['xnview', 'classic'],
#  ['kubernetes'],
#  ['satellite'],
#  ['mediaserver'],
#  ['desktop', 'central', 'msp'],
#  ['linux', 'kernel'],
#  ['android'],
#  ['windows', '8.1'],
#  ['wi-fi', 'protected', 'access'],
#  ['repeated', 'parameters'],
#  ['reader'],
#  ['macos'],
#  ['android'],
#  ['webaccess'],
#  ['httpd'],
#  ['macos'],
#  ['woocommerce', 'plugin'],
#  ['alchemist.vim'],
#  ['reader'],
#  ['fortimail'],
#  ['peoplesoft'],
#  ['imagemagick'],
#  ['sd', '835'],
#  [nan],
#  ['imagemagick'],
#  ['safari'],
#  ['pjlib'],
#  ['asr', '5500'],
#  ['lynx'],
#  ['qemu'],
#  ['loadrunner'],
#  ['peoplesoft'],
#  ['phpmyfaq'],
#  ['binutils'],
#  ['networks', 'northstar', 'controller', 'application'],
#  ['serendipity'],
#  ['pcmanfm'],
#  ['windows', '8.1'],
#  ['windows', 'server', '2012'],
#  ['k7', 'antivirus', 'premium'],
#  ['dgs-1510-20'],
#  ['netvault', 'backup'],
#  ['rational', 'quality', 'manager'],
#  ['mha-al00ac00b125'],
#  ['networks', 'contrail', 'releases'],
#  ['ip', 'phone', '8800', 'series'],
#  ['medfusion', '4000', 'wireless', 'syringe', 'infusion', 'pump'],
#  ['rhapsody', 'dm'],
#  ['linux', 'kernel'],
#  [nan],
#  ['media', 'framework'],
#  ['mediaserver'],
#  ['windows', '8.1'],
#  ['android'],
#  ['gtk-vnc'],
#  ['rational', 'quality', 'manager'],
#  ['yandex', 'browser'],
#  ['metasploit', 'pro'],
#  ['scanmail', 'for', 'exchange'],
#  ['ios'],
#  ['windows', '8.1'],
#  ['xen'],
#  ['easy', 'chat', 'server'],
#  ['rqm'],
#  ['windows', '8.1'],
#  ['peoplesoft'],
#  ['photo,video', 'locker-calculator'],
#  ['linux', 'kernel'],
#  ['nexusphp'],
#  ['macos'],
#  ['windows', '10'],
#  ['process', 'monitor'],
#  ['data', 'protection', 'advisor'],
#  ['disk', 'savvy', 'enterprise'],
#  ['plone'],
#  ['junos'],
#  ['coaxdata', 'gateway', '1gbps', 'devices'],
#  ['newsbeuter'],
#  ['espace', 'u1930'],
#  ['integraxor'],
#  ['android'],
#  ['phpmyfaq'],
#  ['teamspeak'],
#  ['smartcare', 'v200r003c10'],
#  ['android'],
#  ['p10', 'plus', 'smart', 'phones'],
#  ['irfanview'],
#  ['libressl'],
#  ['e-sic'],
#  ['nodejs', 'ejs'],
#  ['linux', 'kernel'],
#  ['linux', 'kernel'],
#  ['reader'],
#  ['nas', 'application', 'media', 'streaming', 'add-on'],
#  ['ncurses'],
#  ['trixbox'],
#  ['pr115-204-p-rs'],
#  ['ios'],
#  ['linux', 'kernel'],
#  ['ios'],
#  ['pfsense'],
#  ['phoenix', 'framework'],
#  ['skyrouter'],
#  ['binutils'],
#  ['symphony', 'cms'],
#  ['sipcrack'],
#  ['vcsa'],
#  ['message', 'handler'],
#  ['mahara', 'mobile'],
#  ['webex'],
#  ['shell'],
#  ['micrologix', '1400', 'series'],
#  ['android'],
#  ['macos'],
#  ['android'],
#  ['kaltura'],
#  ['e-business', 'suite'],
#  ['junos', 'space'],
#  ['windows', '10'],
#  ['stashcat'],
#  ['i-filter'],
#  ['windows', '8.1'],
#  ['ucmdb', 'foundation', 'software'],
#  ['vmware', 'workstation'],
#  ['xen'],
#  ['ise'],
#  ['android'],
#  ['scada', 'web', 'server'],
#  ['phpbb'],
#  ['android'],
#  ['gemirro'],
#  ['android'],
#  ['windows', '7'],
#  ['reader'],
#  ['windows', '8.1'],
#  ['mysql'],
#  ['atutor'],
#  ['android'],
#  ['hospitality', 'applications'],
#  ['emptoris', 'services', 'procurement'],
#  ['net::ldap'],
#  ['wireshark'],
#  ['modx', 'revolution'],
#  ['elastic', 'services', 'controllers'],
#  ['ios'],
#  ['crossenv'],
#  ['android'],
#  ['gstreamer'],
#  ['blue', 'ocean'],
#  ['ise'],
#  ['ikarus', 'anti.virus'],
#  [nan],
#  ['e-business', 'suite'],
#  ['poppler'],
#  ['wp', 'editor.md', 'plugin'],
#  ['codeigniter'],
#  ['gazelle'],
#  ['byucslabsix'],
#  ['linux', 'kernel'],
#  ['imagemagick'],
#  ['imagemagick'],
#  ['http/2'],
#  ['imageworsener'],
#  ['libquicktime'],
#  ['mikrotik'],
#  ['windows', 'products'],
#  ['firefox'],
#  ['lsf031e'],
#  ['ios'],
#  ['poppler'],
#  ['siebel', 'crm'],
#  ['otrs'],
#  ['k7', 'antivirus', 'premium'],
#  ['adobe', 'connect'],
#  ['chakra', 'core'],
#  ['linux', 'kernel'],
#  ['hem-gw26a'],
#  ['html-janitor'],
#  ['thunderbird'],
#  ['bsm',
#   'platform',
#   'application',
#   'performance',
#   'management',
#   'system',
#   'health',
#   'product'],
#  ['android'],
#  ['android'],
#  ['fusion', 'middleware'],
#  ['liferay'],
#  ['routeros'],
#  ['tcpdump'],
#  ['edge'],
#  ['te60', 'v100r001c10'],
#  ['linux', 'kernel'],
#  ['s-mailx'],
#  ['libav'],
#  ['unified', 'communications', 'manager'],
#  ['e-business', 'suite'],
#  ['tcpdump'],
#  ['office'],
#  ['trusted', 'execution', 'environment'],
#  ['workstation'],
#  ['vibe', 'mobile', 'phones'],
#  ['openstack', 'swauth'],
#  ['helpdesk', 'application'],
#  ['exiv2'],
#  ['ios', 'xe', ''],
#  ['classic', 'user', 'self-service'],
#  ['digital', 'editions'],
#  ['foxit', 'reader'],
#  ['linux', 'kernel'],
#  ['utilities', 'applications'],
#  ['firefox'],
#  ['prime', 'collaboration', 'provisioning', 'tool'],
#  ['media', 'framework'],
#  ['autotrace'],
#  ['autotrace'],
#  ['openexif'],
#  ['project', 'and', 'portfolio', 'management', 'center'],
#  ['windows', '8.1'],
#  ['bgo-l03c158b003custc158d001'],
#  ['interactive', 'graphical', 'scada', 'system'],
#  ['tmock'],
#  ['wireshark'],
#  ['xnview', 'classic'],
#  ['b2j_contact'],
#  ['thunderbird'],
#  ['xnview', 'classic'],
#  ['gitlab', 'enterprise', 'edition'],
#  ['business', 'intelligence', 'promotion', 'management', 'application'],
#  ['imagemagick'],
#  ['xep-0280'],
#  ['freeradius'],
#  ['dir-600m'],
#  ['ios'],
#  ['tcpdump'],
#  ['360class.jansenhm'],
#  ['zenbership'],
#  ['digital', 'editions'],
#  ['apng2gif'],
#  ['hicinema'],
#  ['readpcximage'],
#  ['scr02hd'],
#  ['camera', 'driver'],
#  ['k7', 'antivirus', 'premium'],
#  ['isilon', 'onefs'],
#  ['mybb'],
#  ['linux', 'kernel'],
#  ['reader'],
#  ['linux', 'kernel'],
#  ['exiv2'],
#  ['financial', 'services', 'applications'],
#  ['stdu', 'viewer'],
#  ['fusion', 'middleware'],
#  ['cobbler'],
#  ['windows', '7'],
#  ['unified', 'communications', 'manager'],
#  ['android'],
#  ['autotrace'],
#  ['unitrends', 'backup'],
#  ['security', 'access', 'manager', 'appliance'],
#  ['infosphere', 'biginsights'],
#  ['bigtree', 'cms'],
#  ['linux', 'kernel'],
#  ['macos'],
#  ['unified', 'communications', 'manager'],
#  ['mysql'],
#  ['symphony', 'cms'],
#  ['privileged', 'account', 'manager'],
#  ['tcpdump'],
#  ['wildmidi'],
#  ['rubygems'],
#  ['reader'],
#  ['ios'],
#  ['misp'],
#  ['active', 'choices', 'plugin'],
#  ['macos'],
#  ['hub', '2245-222', 'devices'],
#  ['samlify'],
#  ['dir-850l'],
#  ['reader'],
#  ['algonquin', 'state', 'bank', 'mobile', 'banking'],
#  ['viewport'],
#  ['firepower', 'threat', 'defense'],
#  ['freerdp'],
#  ['sterling', 'b2b', 'integrator', 'standard', 'edition'],
#  ['tivoli', 'federated', 'identity', 'manager'],
#  ['progress', 'sitefinity'],
#  ['networks', 'northstar', 'controller', 'application'],
#  ['symfony'],
#  ['linux', 'kernel'],
#  ['gravity'],
#  ['networks', 'northstar', 'controller', 'application'],
#  ['linux', 'kernel'],
#  ['appgoat'],
#  ['mbed', 'tls'],
#  ['autotrace'],
#  ['db2'],
#  ['ios'],
#  ['silverstripe'],
#  ['ffmpeg'],
#  ['tririga', 'application', 'platform'],
#  ['omnibox'],
#  ['ip', 'gateway'],
#  ['goahead'],
#  ['e-business', 'suite'],
#  ['cms', 'made', 'simple'],
#  ['filecapsule', 'deluxe', 'portable'],
#  ['curl'],
#  ['', 'genixcms'],
#  ['graphicsmagick'],
#  ['mediawiki'],
#  ['keycloak'],
#  ['macos'],
#  ['metasploit'],
#  ['mobile-friendly-app-builder-by-easytouch'],
#  ['imagemagick'],
#  ['irfanview'],
#  ['nuxeo'],
#  ['rational', 'software', 'architect', 'design', 'manager'],
#  ['mysql'],
#  ['freexl'],
#  ['linux', 'kernel'],
#  ['linux', 'kernel'],
#  ['windows', '10'],
#  ['security', 'identity', 'governance', 'virtual', 'appliance'],
#  ['xnview', 'classic'],
#  ['appcheck'],
#  ['kanboard'],
#  ['android'],
#  ['ios'],
#  ['edr-810'],
#  ['primedrive', 'desktop', 'application'],
#  ['ucs', 'c-series', 'rack', 'servers'],
#  ['xnview', 'classic'],
#  ['codiad'],
#  ['windows', 'server', '2012'],
#  ['safari'],
#  ['macos'],
#  ['openidm'],
#  ['vir.it', 'explorer', 'lite'],
#  ['geminabox'],
#  ['media', 'framework'],
#  ['r6700'],
#  ['metinfo'],
#  ['mahara'],
#  ['foreman'],
#  ['windows', '7'],
#  ['mediaserver'],
#  ['coldfusion'],
#  ['imagemagick'],
#  ['windows', '8.1'],
#  ['ghostscript', 'ghostxps'],
#  ['graphicsmagick'],
#  ['windows', 'server', '2012'],
#  ['win32k'],
#  ['e-business', 'suite'],
#  ['windows', '7'],
#  ['afm'],
#  ['mysql'],
#  ['private_address_check', 'ruby'],
#  ['mssql'],
#  ['http-proxy'],
#  ['sitecore'],
#  ['ichitaro', 'office'],
#  ['cxf'],
#  ['lon-al00bc00'],
#  ['mssql'],
#  ['http-proxy'],
#  ['sitecore'],
#  ['ichitaro', 'office'],
#  ['cxf'],
#  ['lon-al00bc00']]

# %%
def JaccardSimilarity(list1, list2):
    NaN = [math.nan]
    if list1 == NaN or list2 == NaN:
        return 0
    else:
        union = set(list1).union(set(list2))
        intersection = set(list1).intersection(set(list2))
        return len(intersection)/len(union)

# %%
def Similarity(list1, list2):
    count = 0
    for i in range(1,7):
        if type(list1[i]) == type(list2[i]):
            if type(list1[i]) == type('str'):
                if list1[i] == list2[i]:
                    count += 1
            else:
                if not(math.isnan(list1[i]) or math.isnan(list2[i])):
                    if list1[i] == list2[i]:
                        count += 1
    return count

# %%
weight = []
idx2 = 0

for i in range(len(Sample)):
    for j in range(i+1, len(Sample)):
        s = Similarity(Sample.loc[i, :].tolist(), Sample.loc[j, :].tolist())
        s += JaccardSimilarity(software[i], software[j])
        s /= 7
        s = round(s, 1)
        if(s != 0):
            weight.append([])
            weight[idx2].append(i)
            weight[idx2].append(j)
            weight[idx2].append(s)
            idx2 += 1
            
weight = pd.DataFrame(weight)
weight.columns = ['Source', 'Target', 'Weight']
weight
# Out:
#        Source  Target  Weight
# 0           0       1     0.1
# 1           0       3     0.1
# 2           0       4     0.1
# 3           0       7     0.3
# 4           0       8     0.1
# ...       ...     ...     ...
# 57490     448     451     0.3
# 57491     448     452     0.1
# 57492     449     451     0.1
# 57493     449     452     0.3
# 57494     451     452     0.1
#
# [57495 rows x 3 columns]

# %%
weight.to_csv("Edge.csv", index = False)
